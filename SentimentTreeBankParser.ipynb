# %%
pip install gtrans
# Out:
# ...
#      |████████████████████████████████| 3.8MB 771kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.5MB 15.8MB/s eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-cp37-none-any.whl size=1273 sha256=7c42053c35520f349d90c296ff92b9c406bc5ad5bd8c41a2011af4064dc52f93
#   Stored in directory: /home/judy/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp37-none-any.whl size=1449906 sha256=b06737cb5f3912e207c7e49d09731ce05b410eb3ce2132e89f52e0c72012744c
#   Stored in directory: /home/judy/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# Successfully built bs4 nltk
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtrans import translate_text

f = open("/home/judy/SentimentTreeBank/parsed_train.txt", 'r')
lines = f.readlines()
lines = list(map(lambda s: s.strip(), lines))


for line in lines:
    print(translate_text(line, 'en', 'ko'))
    
f.close()
# Out:
# 가다 .
# 가다
# .
#
# 어.
# 뭐라고
# .
#
# 왜 ?
# 왜
# ?
#
# 와 .
# 와
# .
#
# 예 .
# <class 'selenium.common.exceptions.UnexpectedAlertPresentException'> Alert Text: None
# Message: unexpected alert open: {Alert text : 정보기획팀에서 배포한 Windows PC 자동 보안업데이트(PMS)의 ActiveX가 미설치 되었거나 최신버전이 아닙니다. 설치페이지로 이동합니다.}
#   (Session info: headless chrome=76.0.3809.87)
#   (Driver info: chromedriver=2.36.540471 (9c759b81a907e70363c6312294d30b6ccccc2752),platform=Linux 5.0.0-37-generic x86_64)
#
#
# .
#
# 아니. .
# 아니.
# .
#
# 멋있는 .
# 멋있는
# .
#
# 쾅!
# 쾅
# !
#
# 줌!
# 줌
# !
#
# 어서!
# 씨몬
# !
#
# 이상하다.
# 기묘한
# .
# <class 'selenium.common.exceptions.WebDriverException'> Message: unknown error: Cannot set property 'value' of null
#   (Session info: headless chrome=76.0.3809.87)
#   (Driver info: chromedriver=2.36.540471 (9c759b81a907e70363c6312294d30b6ccccc2752),platform=Linux 5.0.0-37-generic x86_64)
#
#
# 레너?
# 레너
# ?
#
# 거의.
# 거의
# .
#
# 결말.
# 종결
# .
#
# 스파이 대.
# 스파이 대
# .
#
# 제발
# 부디
# .
#
# 터치!
# 터치
# !
#
# 미쳐.
# 지저분한
# ...
